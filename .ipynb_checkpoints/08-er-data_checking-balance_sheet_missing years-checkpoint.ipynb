# %% [markdown]
# So it appears that the code doesn't find some tables, here we investigate why...

# %%
import os
import glob
import importlib

import numpy as np
import pandas as pd

import xbrl_image_parser as xip

from PIL import Image as im
from pytesseract import image_to_data

# %%
importlib.reload(xip)
# Out:
# <module 'xbrl_image_parser' from '/home/edd/Documents/Projects/companies_house/explore/xbrl_image_parser.py'>

# %%
wrk_dir = os.getcwd()
os.chdir(f"{os.getcwd()}/data/old/read_check/wrong")
pdf_lst = glob.glob("*.pdf")
os.chdir(wrk_dir)

# %%
wrk_dir = os.getcwd()
os.chdir(f"{os.getcwd()}/data/old/read_check/right")
comp_pdf_lst = glob.glob("*.pdf")
os.chdir(wrk_dir)

# %%
comp_results_lst = [xip.process_PDF(f"{os.getcwd()}/data/old/read_check/right/{file}")
               for file in comp_pdf_lst]
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/OC347970_2018-08-02.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/06786096_2018-11-29.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/01050578_2018-11-07.pdf
# Performing pre-processing on all png images
# Failed to process line: 000 000 000 000
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/SC281238_2018-11-27.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/09165062_2018-08-30.pdf
# ...

# %%
xip.process_PDF(f"{os.getcwd()}/data/old/read_check/wrong/OC311413_2018-09-14.pdf")
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/OC311413_2018-09-14.pdf
# Performing pre-processing on all png images
#    conf  currYr                                              label  \
# 0  55.0     1.0                                        Investments
# 1  55.0     0.0                                        Investments
# 2  91.0     1.0  Creditors amounts falling due within 3 oneyear...
# 3  88.0     0.0  Creditors amounts falling due within 3 oneyear...
# 4  96.0     1.0              Total assets less current liabilities
# 5  96.0     0.0              Total assets less current liabilities
# 6  96.0     1.0                  Amounts due in respect of profits
# 7  96.0     0.0                  Amounts due in respect of profits
#
#                                               source     value    year  unit
# 0                   Investments 2 32026624 32026 624     32026  2017.0   NaN
# ...

# %%
results_lst = [xip.process_PDF(f"{os.getcwd()}/data/old/read_check/wrong/{file}")
               for file in pdf_lst]
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10582063_2018-10-31.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/03790585_2018-09-30.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/02709473_2019-01-17.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/09618523_2018-02-21.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10832155_2019-02-05.pdf
# Performing pre-processing on all png images
# ...

# %% [markdown]
# ok, lets see if the code is finding the page with the balance shee on or not?
#
# we call the first few lines of code in xbrl_image_passer.process_PDF as list comprehensions so we can see the output from each stage if we wish

# %%
non_empty_results_lst = []
for df,file in zip(results_lst, pdf_lst):
    if not df.empty:
        df["filename"]=file
        non_empty_results_lst.append(df)

# %%
non_empty_results_lst
# Out:
# [   conf  currYr                                              label  \
#  0  55.0     1.0                                        Investments
#  1  55.0     0.0                                        Investments
#  2  91.0     1.0  Creditors amounts falling due within 3 oneyear...
#  3  88.0     0.0  Creditors amounts falling due within 3 oneyear...
#  4  96.0     1.0              Total assets less current liabilities
#  5  96.0     0.0              Total assets less current liabilities
#  6  96.0     1.0                  Amounts due in respect of profits
#  7  96.0     0.0                  Amounts due in respect of profits
#
#                                                source     value    year  unit  \
#  0                   Investments 2 32026624 32026 624     32026  2017.0   NaN
#  1                   Investments 2 32026624 32026 624       624  2016.0   NaN
#  2  oneyear ss 32046099 32040592 Net current liabi...  32046099  2017.0   NaN
# ...

# %% [markdown]
# these two files contain units that aren't searched for. we replace the regex string from
#
# units_regex = "[£$]|million|thousand|£m|£k|$m|$k"
#
# to
#
# units_regex = "[£$]|million|thousand|£m|£k|$m|$k|€|US$"

# %%
curr_check_file_lst= []
for df,file in zip(results_lst, pdf_lst):
    if not df.empty:
        curr_check_file_lst.append(file)

# %%
curr_check_file_lst
# Out:
# ['OC311413_2018-09-14.pdf', '05084383_2018-10-01.pdf']

# %%
curr_check_results = [xip.process_PDF(f"{os.getcwd()}/data/old/read_check/wrong/{file}")
                      for file in curr_check_file_lst]
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/OC311413_2018-09-14.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/05084383_2018-10-01.pdf
# Performing pre-processing on all png images

# %%
curr_check_results[0]
# Out:
#    conf  currYr                                              label  \
# 0  55.0     1.0                                        Investments
# 1  55.0     0.0                                        Investments
# 2  91.0     1.0  Creditors amounts falling due within 3 oneyear...
# 3  88.0     0.0  Creditors amounts falling due within 3 oneyear...
# 4  96.0     1.0              Total assets less current liabilities
# 5  96.0     0.0              Total assets less current liabilities
# 6  96.0     1.0                  Amounts due in respect of profits
# 7  96.0     0.0                  Amounts due in respect of profits
#
#                                               source     value    year unit
# 0                   Investments 2 32026624 32026 624     32026  2017.0  US$
# 1                   Investments 2 32026624 32026 624       624  2016.0  US$
# 2  oneyear ss 32046099 32040592 Net current liabi...  32046099  2017.0  US$
# ...

# %% [markdown]
# So two are not producing data as the currecy was not recognised`

# %%
measurements_lst = [xip.make_measurements(data) for data in data_lst]

# %%
numerical_lst =[]
for measurements in measurements_lst:
    measurements["numerical"] = xip.convert_to_numeric(measurements["text"])
    numerical_lst.append(measurements)

# %%
balance_sheet_pages = [xip.find_balance_sheet_pages(numerical) 
                       for numerical in numerical_lst]

# %%
pages = balance_sheet_pages[0]
numeric_data = numerical_lst[0]

res_df = pd.DataFrame()
# Iterate through balance sheet pages, retrieve everything
for csv_number in pages:
    page_df = numeric_data[numeric_data['csv_num'] == csv_number]

    # Determine where the lines are
    detected_lines = xip.detect_lines(page_df)

    # Get all detectable balance sheet stats
    res_df = res_df.append(xip.extract_lines(page_df, detected_lines) )

# %%
# Out:
# Index(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num',
#        'left', 'top', 'width', 'height', 'conf', 'text', 'csv_num', 'centre_x',
#        'centre_y', 'right', 'bottom', 'area', 'numerical'],
#       dtype='object')

# %%
 numeric_data[numeric_data['csv_num'] == pages[0]]["text"]
# Out:
# 0                None
# 1                None
# 2                None
# 3                None
# 4             ALLISON
# 5             JEFFERY
# 6               LASER
# 7                 AND
# 8                SKIN
# 9              CLINIC
# 10            LIMITED
# 11         Registered
# 12             Number
# 13           10582063
# 14               None
# 15               None
# 16               None
# 17            Balance
# 18              Sheet
# 19                 as
# 20                 at
# 21                 30
# 22           November
# 23               2017
# 24               None
# 25               None
# 26               None
# 27               2017
# 28               None
# 29                  £
#             ...
# 198             using
# 199        electronic
# 200    communications
# 201               and
# 202     authenticated
# 203                in
# 204        accordance
# 205              with
# 206               the
# 207              None
# ...

# %%
pd.Dat`aFrame({"file": pdf_lst,
              "balance_sheet": balance_sheet_pages}).sort_values("file")
# Out:
#                        file balance_sheet
# 8   02119876_2017-09-21.pdf         [3.0]
# 2   02709473_2019-01-17.pdf            []
# 1   03790585_2018-09-30.pdf            []
# 24  04740006_2018-12-09.pdf            []
# 11  05084383_2018-10-01.pdf    [1.0, 2.0]
# 13  05494889_2018-10-01.pdf    [1.0, 4.0]
# 7   06522069_2018-08-21.pdf            []
# 23  06705523_2018-11-19.pdf            []
# 14  09487709_2018-12-14.pdf            []
# 3   09618523_2018-02-21.pdf         [6.0]
# 20  09981158_2017-06-01.pdf         [2.0]
# 18  10070786_2018-10-31.pdf    [4.0, 8.0]
# 22  10341209_2018-05-22.pdf         [2.0]
# 9   10355449_2018-11-06.pdf            []
# 15  10479373_2018-06-21.pdf   [7.0, 11.0]
# 6   10550078_2018-09-26.pdf    [2.0, 3.0]
# 0   10582063_2018-10-31.pdf         [1.0]
# 5   10602392_2018-10-17.pdf         [2.0]
# 16  10611038_2018-11-08.pdf            []
# 21  10655161_2018-11-29.pdf         [1.0]
# 12  10672557_2018-12-12.pdf            []
# ...

# %%
comp_data_lst = [xip.ocr_pdf(f"{os.getcwd()}/data/old/read_check/right/{file}")
                 for file in comp_pdf_lst]
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/OC347970_2018-08-02.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/06786096_2018-11-29.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/01050578_2018-11-07.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/SC281238_2018-11-27.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/right/09165062_2018-08-30.pdf
# Performing pre-processing on all png images
# ...

# %%
comp_measurements_lst = [xip.make_measurements(data) for data in comp_data_lst]

# %%
comp_numerical_lst =[]
for measurements in comp_measurements_lst:
    measurements["numerical"] = xip.convert_to_numeric(measurements["text"])
    comp_numerical_lst.append(measurements)

# %%
comp_balance_sheet_pages = [xip.find_balance_sheet_pages(numerical) 
                            for numerical in comp_numerical_lst]

# %%
pd.DataFrame({"file": comp_pdf_lst,
              "balance_sheet": comp_balance_sheet_pages}).sort_values("file")
# Out:
#                        file       balance_sheet
# 2   01050578_2018-11-07.pdf              [10.0]
# 19  01557781_2019-01-24.pdf               [2.0]
# 16  01684721_2018-05-24.pdf          [5.0, 8.0]
# 11  01836313_2018-09-30.pdf              [16.0]
# 12  02119606_2018-07-31.pdf          [7.0, 9.0]
# 7   04925061_2018-08-16.pdf          [3.0, 9.0]
# 18  05105318_2019-01-14.pdf               [3.0]
# 15  05242411_2018-03-21.pdf          [3.0, 8.0]
# 10  06363165_2018-03-07.pdf          [4.0, 5.0]
# 6   06377386_2018-09-21.pdf               [5.0]
# 1   06786096_2018-11-29.pdf               [1.0]
# 20  08673651_2018-09-18.pdf          [4.0, 6.0]
# 5   08778584_2018-09-03.pdf               [2.0]
# 23  09001323_2017-11-23.pdf               [4.0]
# 4   09165062_2018-08-30.pdf     [3.0, 5.0, 6.0]
# 14  09708034_2018-05-22.pdf          [2.0, 3.0]
# 13  09905204_2019-01-28.pdf              [20.0]
# 8   10089373_2017-12-28.pdf          [5.0, 6.0]
# 24  10155776_2018-05-07.pdf               [1.0]
# ...

# %% [markdown]
# we can flatten

# %%
pages_lst
# Out:
# [1.0,
#  6.0,
#  2.0,
#  2.0,
#  2.0,
#  3.0,
#  3.0,
#  3.0,
#  1.0,
#  2.0,
#  1.0,
#  4.0,
#  7.0,
#  11.0,
#  3.0,
#  4.0,
#  8.0,
#  3.0,
#  2.0,
#  1.0,
#  2.0]

# %%
test_pdf = f"{os.getcwd()}/data/old/read_check/{pdf_lst[0]}"

# %%
test_pdf
# Out:
# '/home/edd/Documents/Projects/companies_house/explore/data/old/read_check/10582063_2018-10-31.pdf'

# %%
results = xip.process_PDF(test_pdf)
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/10582063_2018-10-31.pdf
# Performing pre-processing on all png images
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/share/virtualenvs/explore-1I3eoxiK/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'currYr'
#
# ...

# %%
data = xip.ocr_pdf(test_pdf)
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/10582063_2018-10-31.pdf
# Performing pre-processing on all png images

# %%
data = xip.make_measurements(data)

# %%
data["numerical"] = xip.convert_to_numeric(data["text"])

# %%
csv_numbers = xip.find_balance_sheet_pages(data)

# %%
page_df =data[[x in csv_numbers for x in data["csv_num"]]]

# %%
lines = xip.detect_lines(page_df)

# %%
lines
# Out:
# [{'left': 0, 'right': 2480, 'top': 214, 'bottom': 259},
#  {'left': 0, 'right': 2480, 'top': 561, 'bottom': 595},
#  {'left': 0, 'right': 2480, 'top': 684, 'bottom': 720},
#  {'left': 0, 'right': 2480, 'top': 751, 'bottom': 784},
#  {'left': 0, 'right': 2480, 'top': 816, 'bottom': 862},
#  {'left': 0, 'right': 2480, 'top': 886, 'bottom': 922},
#  {'left': 0, 'right': 2480, 'top': 955, 'bottom': 1000},
#  {'left': 0, 'right': 2480, 'top': 1021, 'bottom': 1066},
#  {'left': 0, 'right': 2480, 'top': 1092, 'bottom': 1128},
#  {'left': 0, 'right': 2480, 'top': 1186, 'bottom': 1221},
#  {'left': 0, 'right': 2480, 'top': 1308, 'bottom': 1353},
#  {'left': 0, 'right': 2480, 'top': 1374, 'bottom': 1419},
#  {'left': 0, 'right': 2480, 'top': 1439, 'bottom': 1485},
#  {'left': 0, 'right': 2480, 'top': 1505, 'bottom': 1551},
#  {'left': 0, 'right': 2480, 'top': 1571, 'bottom': 1617},
#  {'left': 0, 'right': 2480, 'top': 1638, 'bottom': 1682},
# ...

# %%
xip.extract_lines(page_df, lines)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
png =  xip.pdf_to_png(test_pdf)

# %%
png
# Out:
# '/home/edd/Documents/Projects/companies_house/explore/data/old/read_check/10582063_2018-10-31'

# %%
png_lst = xip.pre_process(png)

# %%
image_to_data(im.open(png_lst[0]))
# Out:
# "level\tpage_num\tblock_num\tpar_num\tline_num\tword_num\tleft\ttop\twidth\theight\tconf\ttext\n1\t1\t0\t0\t0\t0\t0\t0\t2480\t3509\t-1\t\n2\t1\t1\t0\t0\t0\t178\t214\t2123\t45\t-1\t\n3\t1\t1\t1\t0\t0\t178\t214\t2123\t45\t-1\t\n4\t1\t1\t1\t1\t0\t178\t214\t2123\t45\t-1\t\n5\t1\t1\t1\t1\t1\t178\t214\t222\t35\t96\tALLISON\n5\t1\t1\t1\t1\t2\t415\t214\t224\t35\t96\tJEFFERY\n5\t1\t1\t1\t1\t3\t654\t214\t165\t35\t96\tLASER\n5\t1\t1\t1\t1\t4\t832\t214\t104\t35\t96\tAND\n5\t1\t1\t1\t1\t5\t954\t214\t117\t35\t96\tSKIN\n5\t1\t1\t1\t1\t6\t1088\t214\t175\t35\t96\tCLINIC\n5\t1\t1\t1\t1\t7\t1280\t214\t217\t35\t96\tLIMITED\n5\t1\t1\t1\t1\t8\t1677\t214\t224\t45\t95\tRegistered\n5\t1\t1\t1\t1\t9\t1918\t214\t173\t35\t96\tNumber\n5\t1\t1\t1\t1\t10\t2108\t214\t193\t35\t95\t10582063\n2\t1\t2\t0\t0\t0\t834\t561\t814\t34\t-1\t\n3\t1\t2\t1\t0\t0\t834\t561\t814\t34\t-1\t\n4\t1\t2\t1\t1\t0\t834\t561\t814\t34\t-1\t\n5\t1\t2\t1\t1\t1\t834\t561\t167\t34\t96\tBalance\n5\t1\t2\t1\t1\t2\t1015\t561\t115\t34\t96\tSheet\n5
# ...

# %%
 data = xip.ocr_pdf(test_pdf)
# Out:
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/10582063_2018-10-31.pdf
# Performing pre-processing on all png images

# %%
data = xip.make_measurements(data)

# %%
data
# Out:
#      level  page_num  block_num  par_num  line_num  word_num  left   top  \
# 0        1         1          0        0         0         0     0     0
# 1        2         1          1        0         0         0   178   214
# 2        3         1          1        1         0         0   178   214
# 3        4         1          1        1         1         0   178   214
# 4        5         1          1        1         1         1   178   214
# 5        5         1          1        1         1         2   415   214
# 6        5         1          1        1         1         3   654   214
# 7        5         1          1        1         1         4   832   214
# 8        5         1          1        1         1         5   954   214
# 9        5         1          1        1         1         6  1088   214
# 10       5         1          1        1         1         7  1280   214
# 11       5         1          1        1         1         8  1677   214
# ...
