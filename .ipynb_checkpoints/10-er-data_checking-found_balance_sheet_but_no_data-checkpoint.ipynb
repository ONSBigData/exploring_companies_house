# %%
import os
import glob
import importlib
import re

import numpy as np
import pandas as pd


import xbrl_image_parser as xip

from IPython.display import HTML
from tqdm import tqdm_notebook
from PIL import Image as im
from pytesseract import image_to_data

# %%
wrk_dir = os.getcwd()
os.chdir(f"{os.getcwd()}/data/old/read_check/wrong")
pdf_lst = glob.glob("*.pdf")
os.chdir(wrk_dir)

# %%
wrk_dir = os.getcwd()
os.chdir(f"{os.getcwd()}/data/old/read_check/right")
comp_pdf_lst = glob.glob("*.pdf")
os.chdir(wrk_dir)

# %% [markdown]
# we follow each step in xip.process_PDF and see where it gets us

# %%
data_lst = [xip.ocr_pdf(f"{os.getcwd()}/data/old/read_check/wrong/{file}")
            for file in tqdm_notebook(pdf_lst)]
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10582063_2018-10-31.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/03790585_2018-09-30.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/02709473_2019-01-17.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/09618523_2018-02-21.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10832155_2019-02-05.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10602392_2018-10-17.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10550078_2018-09-26.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/06522069_2018-08-21.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/02119876_2017-09-21.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10355449_2018-11-06.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/OC311413_2018-09-14.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/05084383_2018-10-01.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10672557_2018-12-12.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/05494889_2018-10-01.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/09487709_2018-12-14.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10479373_2018-06-21.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10611038_2018-11-08.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10939817_2018-12-12.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10070786_2018-10-31.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/SC307593_2017-11-24.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/09981158_2017-06-01.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10655161_2018-11-29.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/10341209_2018-05-22.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/06705523_2018-11-19.pdf
# Performing pre-processing on all png images
# Converting PDF image to multiple png files
# /home/edd/Documents/Projects/companies_house/explore/data/old/read_check/wrong/04740006_2018-12-09.pdf
# Performing pre-processing on all png images

# %%
data_cords_lst = [xip.make_measurements(data) 
                  for data in tqdm_notebook(data_lst)]
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
data_lst[0].columns.to_list()
# Out:
# ['level',
#  'page_num',
#  'block_num',
#  'par_num',
#  'line_num',
#  'word_num',
#  'left',
#  'top',
#  'width',
#  'height',
#  'conf',
#  'text',
#  'csv_num',
#  'centre_x',
#  'centre_y',
#  'right',
#  'bottom',
#  'area']

# %%
data_cords_lst[0].columns.to_list()
# Out:
# ['level',
#  'page_num',
#  'block_num',
#  'par_num',
#  'line_num',
#  'word_num',
#  'left',
#  'top',
#  'width',
#  'height',
#  'conf',
#  'text',
#  'csv_num',
#  'centre_x',
#  'centre_y',
#  'right',
#  'bottom',
#  'area']

# %%
data_numeric_lst = []
for data in tqdm_notebook(data_cords_lst):
    data["numerical"] = xip.convert_to_numeric(data['text'])
    data_numeric_lst.append(data)
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
data_numeric_lst[0].columns.to_list()
# Out:
# ['level',
#  'page_num',
#  'block_num',
#  'par_num',
#  'line_num',
#  'word_num',
#  'left',
#  'top',
#  'width',
#  'height',
#  'conf',
#  'text',
#  'csv_num',
#  'centre_x',
#  'centre_y',
#  'right',
#  'bottom',
#  'area',
#  'numerical']

# %%
balance_pages_lst = [xip.find_balance_sheet_pages(data)
                     for data in tqdm_notebook(data_numeric_lst)]
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
balance_pages_df = pd.DataFrame({"file" : pdf_lst,
                                 "balance_pages" : balance_pages_lst
                                })

# %%
balance_pages_df
# Out:
#                        file balance_pages
# 0   10582063_2018-10-31.pdf         [1.0]
# 1   03790585_2018-09-30.pdf            []
# 2   02709473_2019-01-17.pdf            []
# 3   09618523_2018-02-21.pdf         [6.0]
# 4   10832155_2019-02-05.pdf         [2.0]
# 5   10602392_2018-10-17.pdf         [2.0]
# 6   10550078_2018-09-26.pdf    [2.0, 3.0]
# 7   06522069_2018-08-21.pdf            []
# 8   02119876_2017-09-21.pdf         [3.0]
# 9   10355449_2018-11-06.pdf            []
# 10  OC311413_2018-09-14.pdf         [3.0]
# 11  05084383_2018-10-01.pdf    [1.0, 2.0]
# 12  10672557_2018-12-12.pdf            []
# 13  05494889_2018-10-01.pdf    [1.0, 4.0]
# 14  09487709_2018-12-14.pdf            []
# 15  10479373_2018-06-21.pdf   [7.0, 11.0]
# 16  10611038_2018-11-08.pdf            []
# 17  10939817_2018-12-12.pdf         [3.0]
# 18  10070786_2018-10-31.pdf    [4.0, 8.0]
# 19  SC307593_2017-11-24.pdf         [3.0]
# 20  09981158_2017-06-01.pdf         [2.0]
# 21  10655161_2018-11-29.pdf         [1.0]
# 22  10341209_2018-05-22.pdf         [2.0]
# 23  06705523_2018-11-19.pdf            []
# 24  04740006_2018-12-09.pdf            []

# %%
balance_page_mask = [not not row.balance_pages for index, row in balance_pages_df.iterrows()]
balance_page_count = sum(balance_page_mask)

# %%
balance_page_count
# Out:
# 16

# %% [markdown]
# We have pages returning at least one balance page, but no data

# %%
balance_pages_df[balance_page_mask]
# Out:
#                        file balance_pages
# 0   10582063_2018-10-31.pdf         [1.0]
# 3   09618523_2018-02-21.pdf         [6.0]
# 4   10832155_2019-02-05.pdf         [2.0]
# 5   10602392_2018-10-17.pdf         [2.0]
# 6   10550078_2018-09-26.pdf    [2.0, 3.0]
# 8   02119876_2017-09-21.pdf         [3.0]
# 10  OC311413_2018-09-14.pdf         [3.0]
# 11  05084383_2018-10-01.pdf    [1.0, 2.0]
# 13  05494889_2018-10-01.pdf    [1.0, 4.0]
# 15  10479373_2018-06-21.pdf   [7.0, 11.0]
# 17  10939817_2018-12-12.pdf         [3.0]
# 18  10070786_2018-10-31.pdf    [4.0, 8.0]
# 19  SC307593_2017-11-24.pdf         [3.0]
# 20  09981158_2017-06-01.pdf         [2.0]
# 21  10655161_2018-11-29.pdf         [1.0]
# 22  10341209_2018-05-22.pdf         [2.0]

# %% [markdown]
# let's take the first one and see how it do
#
# ... taken (and slightly modified) from xip.process_PDF

# %%
# Out:
#      level  page_num  block_num  par_num  line_num  word_num  left   top  \
# 0        1         1          0        0         0         0     0     0
# 1        2         1          1        0         0         0   178   214
# 2        3         1          1        1         0         0   178   214
# 3        4         1          1        1         1         0   178   214
# 4        5         1          1        1         1         1   178   214
# 5        5         1          1        1         1         2   415   214
# 6        5         1          1        1         1         3   654   214
# 7        5         1          1        1         1         4   832   214
# 8        5         1          1        1         1         5   954   214
# 9        5         1          1        1         1         6  1088   214
# 10       5         1          1        1         1         7  1280   214
# 11       5         1          1        1         1         8  1677   214
# 12       5         1          1        1         1         9  1918   214
# 13       5         1          1        1         1        10  2108   214
# 14       2         1          2        0         0         0   834   561
# 20      39      31    95          at        1    1221.5     579.5   1241
# 21      46      34    95          30        1    1279.0     578.0   1302
# 22     219      34    95    November        1    1428.5     578.0   1538
# 23      95      34    96        2017        1    1600.5     578.0   1648
# 24    1911     537    -1        None        1    1135.5     952.5   2091
# 25    1911     537    -1        None        1    1135.5     952.5   2091
# 26      97      36    -1        None        1    2042.5     702.0   2091
# 27      97      36    96        2017        1    2042.5     702.0   2091
# 28      22      33    -1        None        1    2080.0     767.5   2091
# 29      22      33    92           £        1    2080.0     767.5   2091
# ..     ...     ...   ...         ...      ...       ...       ...    ...
# 222     43      35    96          of        1    2228.5    2285.5   2250
# 223    504      45    -1        None        1     430.0    2355.5    682
# 224     59      36    96         the        1     207.5    2351.0    237
# 225    222      45    96   Companies        1     363.0    2355.5    474
# 226     70      34    96         Act        1     524.0    2350.0    559
# 227    109      36    89       2006.        1     627.5    2351.0    682
# 0     2480    3509    -1        None        2    1240.0    1754.5   2480
# 1     1320     280    -1        None        2    1241.0     329.0   1901
# 2     1320     280    -1        None        2    1241.0     329.0   1901
# 3      624      45    -1        None        2    1241.0     211.5   1553
# 4      223      45    96  Registered        2    1040.5     211.5   1152
# 5      176      34    96      Number        2    1255.0     206.0   1343
# 6      192      34    96    10582063        2    1457.0     206.0   1553
# 7     1320      34    -1        None        2    1241.0     329.0   1901
# 8      221      34    95     ALLISON        2     691.5     329.0    802
# 9      222      33    95     JEFFERY        2     928.0     329.5   1039
# 10     164      34    95       LASER        2    1137.0     329.0   1219
# 11     105      32    95         AND        2    1285.5     329.0   1338
# 12     118      34    95        SKIN        2    1414.0     329.0   1473
# 13     175      33    96      CLINIC        2    1577.5     329.5   1665
# 14     219      32    96     LIMITED        2    1791.5     329.0   1901
# 15     402      34    -1        None        2    1241.0     452.0   1442
# 16     193      34    96     Dormant        2    1136.5     452.0   1233
# 17     195      34    96    Accounts        2    1344.5     452.0   1442
# 18     395      36    -1        None        2    1241.5     574.0   1439
# 19     395      36    -1        None        2    1241.5     574.0   1439
# 20     395      36    -1        None        2    1241.5     574.0   1439
# 21      47      36    95          30        2    1067.5     574.0   1091
# 22     219      34    95    November        2    1216.5     575.0   1326
# 23      98      36    96        2017        2    1390.0     574.0   1439
#
#      bottom     area   numerical
# 0      3509  8702320         NaN
# 1       259    95535         NaN
# 2       259    95535         NaN
# 3       259    95535         NaN
# 4       249     7770         NaN
# 5       249     7840         NaN
# 6       249     5775         NaN
# 7       249     3640         NaN
# 8       249     4095         NaN
# 9       249     6125         NaN
# 10      249     7595         NaN
# 11      259    10080         NaN
# 12      249     6055         NaN
# 13      249     6755  10582063.0
# 14      595    27676         NaN
# 15      595    27676         NaN
# 16      595    27676         NaN
# 17      595     5678         NaN
# 18      595     3910         NaN
# 19      595      936         NaN
# 20      595     1209         NaN
# 21      595     1564        30.0
# 22      595     7446         NaN
# 23      595     3230      2017.0
# 24     1221  1026207         NaN
# 25     1221  1026207         NaN
# 26      720     3492         NaN
# 27      720     3492      2017.0
# 28      784      726         NaN
# 29      784      726         NaN
# ..      ...      ...         ...
# 222    2303     1505         NaN
# 223    2378    22680         NaN
# 224    2369     2124         NaN
# 225    2378     9990         NaN
# 226    2367     2380         NaN
# 227    2369     3924      2006.0
# 0      3509  8702320         NaN
# 1       469   369600         NaN
# 2       469   369600         NaN
# 3       234    28080         NaN
# 4       234    10035         NaN
# 5       223     5984         NaN
# 6       223     6528  10582063.0
# 7       346    44880         NaN
# 8       346     7514         NaN
# 9       346     7326         NaN
# 10      346     5576         NaN
# 11      345     3360         NaN
# 12      346     4012         NaN
# 13      346     5775         NaN
# 14      345     7008         NaN
# 15      469    13668         NaN
# 16      469     6562         NaN
# 17      469     6630         NaN
# 18      592    14220         NaN
# 19      592    14220         NaN
# 20      592    14220         NaN
# 21      592     1692        30.0
# 22      592     7446         NaN
# 23      592     3528      2017.0
#
# [252 rows x 19 columns]

# %%
csv_number = balance_pages_df.balance_pages[0][0]
data = data_numeric_lst[0]

page_df = data[data['csv_num'] == csv_number]

# Determine where the lines are
detected_lines = xip.detect_lines(page_df)

# Get all detectable balance sheet stats
results = xip.extract_lines(page_df, detected_lines)

# %%
page_df.text.to_list()
# Out:
# [None,
#  None,
#  None,
#  None,
#  'ALLISON',
#  'JEFFERY',
#  'LASER',
#  'AND',
#  'SKIN',
#  'CLINIC',
#  'LIMITED',
#  'Registered',
#  'Number',
#  '10582063',
#  None,
#  None,
#  None,
#  'Balance',
#  'Sheet',
#  'as',
#  'at',
#  '30',
#  'November',
#  '2017',
#  None,
#  None,
#  None,
#  '2017',
#  None,
#  '£',
#  None,
#  'Called',
#  'up',
#  'share',
#  'capital',
#  'not',
#  'paid',
#  '100',
#  None,
#  'Net',
#  'assets',
#  '100',
#  None,
#  'Issued',
#  'share',
#  'capital',
#  None,
#  '100',
#  'Ordinary',
#  'Shares',
#  'of',
#  '£',
#  '1',
#  'each',
#  '100',
#  None,
#  'Total',
#  'Shareholder',
#  'funds',
#  '100',
#  None,
#  'STATEMENTS',
#  None,
#  None,
#  None,
#  'a.',
#  'For',
#  'the',
#  'year',
#  'ending',
#  '30',
#  'November',
#  '2017',
#  'the',
#  'company',
#  'was',
#  'entitled',
#  'to',
#  'exemption',
#  'under',
#  'section',
#  '480',
#  None,
#  'of',
#  'the',
#  'Companies',
#  'Act',
#  '2006',
#  'relating',
#  'to',
#  'dormant',
#  'companies.',
#  None,
#  None,
#  'b.',
#  'The',
#  'members',
#  'have',
#  'not',
#  'required',
#  'the',
#  'company',
#  'to',
#  'obtain',
#  'an',
#  'audit',
#  'in',
#  'accordance',
#  'with',
#  'section',
#  '476',
#  'of',
#  None,
#  'the',
#  'Companies',
#  'Act',
#  '2006.',
#  None,
#  None,
#  'c.',
#  'The',
#  'directors',
#  'acknowledge',
#  'their',
#  'responsibilities',
#  'for',
#  'complying',
#  'with',
#  'the',
#  'requirements',
#  'of',
#  'the',
#  'Act',
#  None,
#  'with',
#  'respect',
#  'to',
#  'accounting',
#  'records',
#  'and',
#  'the',
#  'preparation',
#  'of',
#  'accounts.',
#  None,
#  None,
#  'd.',
#  'These',
#  'accounts',
#  'have',
#  'been',
#  'prepared',
#  'in',
#  'accordance',
#  'with',
#  'the',
#  'provisions',
#  'applicable',
#  'to',
#  'companies',
#  None,
#  'subject',
#  'to',
#  'the',
#  'small',
#  'companies',
#  'regime,',
#  None,
#  None,
#  None,
#  'Approved',
#  'by',
#  'the',
#  'Board',
#  'on',
#  '31',
#  'October',
#  '2018',
#  None,
#  None,
#  None,
#  'And',
#  'signed',
#  'on',
#  'their',
#  'behalf',
#  'by:',
#  None,
#  'Allison',
#  'Jeffery,',
#  'Director',
#  None,
#  None,
#  None,
#  'This',
#  'document',
#  'was',
#  'delivered',
#  'using',
#  'electronic',
#  'communications',
#  'and',
#  'authenticated',
#  'in',
#  'accordance',
#  'with',
#  'the',
#  None,
#  "registrar's",
#  'rules',
#  'relating',
#  'to',
#  'electronic',
#  'form,',
#  'authentication',
#  'and',
#  'manner',
#  'of',
#  'delivery',
#  'under',
#  'section',
#  '1072',
#  'of',
#  None,
#  'the',
#  'Companies',
#  'Act',
#  '2006.']

# %% [markdown]
# So we pull out the correct page with the information on there.

# %%
detected_lines
# Out:
# [{'left': 0, 'right': 2480, 'top': 214, 'bottom': 259},
#  {'left': 0, 'right': 2480, 'top': 561, 'bottom': 595},
#  {'left': 0, 'right': 2480, 'top': 684, 'bottom': 720},
#  {'left': 0, 'right': 2480, 'top': 751, 'bottom': 784},
#  {'left': 0, 'right': 2480, 'top': 816, 'bottom': 862},
#  {'left': 0, 'right': 2480, 'top': 886, 'bottom': 922},
#  {'left': 0, 'right': 2480, 'top': 955, 'bottom': 1000},
#  {'left': 0, 'right': 2480, 'top': 1021, 'bottom': 1066},
#  {'left': 0, 'right': 2480, 'top': 1092, 'bottom': 1128},
#  {'left': 0, 'right': 2480, 'top': 1186, 'bottom': 1221},
#  {'left': 0, 'right': 2480, 'top': 1308, 'bottom': 1353},
#  {'left': 0, 'right': 2480, 'top': 1374, 'bottom': 1419},
#  {'left': 0, 'right': 2480, 'top': 1439, 'bottom': 1485},
#  {'left': 0, 'right': 2480, 'top': 1505, 'bottom': 1551},
#  {'left': 0, 'right': 2480, 'top': 1571, 'bottom': 1617},
#  {'left': 0, 'right': 2480, 'top': 1638, 'bottom': 1682},
#  {'left': 0, 'right': 2480, 'top': 1703, 'bottom': 1748},
#  {'left': 0, 'right': 2480, 'top': 1769, 'bottom': 1815},
#  {'left': 0, 'right': 2480, 'top': 1890, 'bottom': 1935},
#  {'left': 0, 'right': 2480, 'top': 2013, 'bottom': 2058},
#  {'left': 0, 'right': 2480, 'top': 2081, 'bottom': 2124},
#  {'left': 0, 'right': 2480, 'top': 2201, 'bottom': 2247},
#  {'left': 0, 'right': 2480, 'top': 2267, 'bottom': 2312},
#  {'left': 0, 'right': 2480, 'top': 2333, 'bottom': 2378}]

# %% [markdown]
# we detect some lines....

# %%
results
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>5</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>10</td>
#       <td>2108</td>
#       <td>214</td>
#       <td>193</td>
#       <td>35</td>
#       <td>95</td>
#       <td>10582063</td>
#       <td>1</td>
#       <td>2204.5</td>
#       <td>231.5</td>
#       <td>2301</td>
#       <td>249</td>
#       <td>6755</td>
#       <td>10582063.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>834</td>
#       <td>561</td>
#       <td>167</td>
#       <td>34</td>
#       <td>96</td>
#       <td>Balance</td>
#       <td>1</td>
#       <td>917.5</td>
#       <td>578.0</td>
#       <td>1001</td>
#       <td>595</td>
#       <td>5678</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1015</td>
#       <td>561</td>
#       <td>115</td>
#       <td>34</td>
#       <td>96</td>
#       <td>Sheet</td>
#       <td>1</td>
#       <td>1072.5</td>
#       <td>578.0</td>
#       <td>1130</td>
#       <td>595</td>
#       <td>3910</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1146</td>
#       <td>571</td>
#       <td>39</td>
#       <td>24</td>
#       <td>95</td>
#       <td>as</td>
#       <td>1</td>
#       <td>1165.5</td>
#       <td>583.0</td>
#       <td>1185</td>
#       <td>595</td>
#       <td>936</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>4</td>
#       <td>1202</td>
#       <td>564</td>
#       <td>39</td>
#       <td>31</td>
#       <td>95</td>
#       <td>at</td>
#       <td>1</td>
#       <td>1221.5</td>
#       <td>579.5</td>
#       <td>1241</td>
#       <td>595</td>
#       <td>1209</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>5</td>
#       <td>1256</td>
#       <td>561</td>
#       <td>46</td>
#       <td>34</td>
#       <td>95</td>
#       <td>30</td>
#       <td>1</td>
#       <td>1279.0</td>
#       <td>578.0</td>
#       <td>1302</td>
#       <td>595</td>
#       <td>1564</td>
#       <td>30.0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>6</td>
#       <td>1319</td>
#       <td>561</td>
#       <td>219</td>
#       <td>34</td>
#       <td>95</td>
#       <td>November</td>
#       <td>1</td>
#       <td>1428.5</td>
#       <td>578.0</td>
#       <td>1538</td>
#       <td>595</td>
#       <td>7446</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>7</td>
#       <td>1553</td>
#       <td>561</td>
#       <td>95</td>
#       <td>34</td>
#       <td>96</td>
#       <td>2017</td>
#       <td>1</td>
#       <td>1600.5</td>
#       <td>578.0</td>
#       <td>1648</td>
#       <td>595</td>
#       <td>3230</td>
#       <td>2017.0</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>5</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1994</td>
#       <td>684</td>
#       <td>97</td>
#       <td>36</td>
#       <td>96</td>
#       <td>2017</td>
#       <td>1</td>
#       <td>2042.5</td>
#       <td>702.0</td>
#       <td>2091</td>
#       <td>720</td>
#       <td>3492</td>
#       <td>2017.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>5</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2069</td>
#       <td>751</td>
#       <td>22</td>
#       <td>33</td>
#       <td>92</td>
#       <td>£</td>
#       <td>1</td>
#       <td>2080.0</td>
#       <td>767.5</td>
#       <td>2091</td>
#       <td>784</td>
#       <td>726</td>
#       <td>NaN</td>
#     </tr>
#     <tr>

# %% [markdown]
# cool, we select words and that

# %%
for line in detected_lines:
    inline = (words_df['bottom'] <= line['bottom']) & (words_df['top'] >= line['top'])
    line_text = " ".join([str(x) for x in words_df[inline]['text']] )
    line_text = re.sub(r'[^a-zA-Z0-9. +]', "", line_text)

# %%
line_text
# Out:
# 'the Companies Act 2006.'

# %%
re.match(finance_regex, line_text)

# %% [markdown]
# so, we don't pull out any of the important data

# %%
inline.to_list()
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True]

# %% [markdown]
# Looks like the lines doesn't match the text...
