# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plot


from sklearn.linear_model import LogisticRegression


from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ROCAUC
from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ClassPredictionError
from yellowbrick.classifier import DiscriminationThreshold

# %% [markdown]
# take the data that has been checked

# %%
sus_df = pd.read_csv(f"{os.getcwd()}/data/old/to_check/data_check_in_progress.csv",
                     index_col=0,
                     encoding="latin-1")

# %%
conf_df = pd.read_csv(f"{os.getcwd()}/data/old/conf_check/to_check-in_progress.csv",
                     index_col=0,
                     encoding="latin-1")

# %% [markdown]
# chaange column names to match

# %%
conf_df.rename(columns={"comments":"notes",
                        "file_name":"filename"}, inplace=True)

# %%
# Out:
# Index(['conf', 'conf_quart', 'filename', 'OK?', 'notes', 'label', 'value',
#        'year', 'unit'],
#       dtype='object')

# %%
conf_df
# Out:
#      conf  conf_quart             filename  OK? notes  \
# 266    96           2  00757019_2018-11-15    y   NaN
# 267    95           2  00757019_2018-11-15    y   NaN
# 268    96           2  00757019_2018-11-15    y   NaN
# 269    96           2  00757019_2018-11-15    y   NaN
# 270    96           2  00757019_2018-11-15    y   NaN
# 271    96           2  00757019_2018-11-15    y   NaN
# 272    96           2  00757019_2018-11-15    y   NaN
# 273    96           2  00757019_2018-11-15    y   NaN
# 274    96           2  00757019_2018-11-15    y   NaN
# 275    83           2  00757019_2018-11-15    y   NaN
# 276    86           2  00757019_2018-11-15    y   NaN
# 277    96           2  00757019_2018-11-15    y   NaN
# 278    96           2  00757019_2018-11-15    y   NaN
# 279    96           2  00757019_2018-11-15    y   NaN
# 280    96           2  00757019_2018-11-15    y   NaN
# 281    96           2  00757019_2018-11-15    y   NaN
# 282    96           2  00757019_2018-11-15    y   NaN
# 283    67           2  00757019_2018-11-15    y   NaN
# 284    96           2  00757019_2018-11-15    y   NaN
# 285    96           2  00757019_2018-11-15    y   NaN
# 286    95           2  00757019_2018-11-15    y   NaN
# 287    96           2  00757019_2018-11-15    y   NaN
# 14     96           4  01848334_2018-11-19    y   NaN
# 15     94           4  01848334_2018-11-19    y   NaN
# 16     96           4  01848334_2018-11-19    y   NaN
# 17     96           4  01848334_2018-11-19    y   NaN
# 18     96           4  01848334_2018-11-19    y   NaN
# 19     96           4  01848334_2018-11-19    y   NaN
# 20     95           4  01848334_2018-11-19    y   NaN
# 21     95           4  01848334_2018-11-19    y   NaN
# ..    ...         ...                  ...  ...   ...
# 674    96           2  SC094096_2018-10-03  NaN   NaN
# 675    96           2  SC094096_2018-10-03  NaN   NaN
# 676    94           2  SC094096_2018-10-03  NaN   NaN
# 677    96           2  SC094096_2018-10-03  NaN   NaN
# 678    94           2  SC094096_2018-10-03  NaN   NaN
# 679    96           2  SC094096_2018-10-03  NaN   NaN
# 680    95           2  SC094096_2018-10-03  NaN   NaN
# 681    96           2  SC094096_2018-10-03  NaN   NaN
# 682    96           2  SC094096_2018-10-03  NaN   NaN
# 683    96           2  SC094096_2018-10-03  NaN   NaN
# 684    96           2  SC094096_2018-10-03  NaN   NaN
# 685    97           2  SC094096_2018-10-03  NaN   NaN
# 686    96           2  SC094096_2018-10-03  NaN   NaN
# 687    97           2  SC094096_2018-10-03  NaN   NaN
# 688    90           2  SC094096_2018-10-03  NaN   NaN
# 689    96           2  SC094096_2018-10-03  NaN   NaN
# 690    96           2  SC094096_2018-10-03  NaN   NaN
# 691    95           2  SC094096_2018-10-03  NaN   NaN
# 692    96           2  SC094096_2018-10-03  NaN   NaN
# 693    95           2  SC094096_2018-10-03  NaN   NaN
# 694    96           2  SC094096_2018-10-03  NaN   NaN
# 695    88           2  SC094096_2018-10-03  NaN   NaN
# 696    96           2  SC094096_2018-10-03  NaN   NaN
# 697    96           2  SC094096_2018-10-03  NaN   NaN
# 698    96           2  SC094096_2018-10-03  NaN   NaN
# 699    95           2  SC094096_2018-10-03  NaN   NaN
# 700    95           2  SC094096_2018-10-03  NaN   NaN
# 701    94           2  SC094096_2018-10-03  NaN   NaN
# 702    96           2  SC094096_2018-10-03  NaN   NaN
# 703    96           2  SC094096_2018-10-03  NaN   NaN
#
#                                                  label    value  year unit
# 266                                    tangible assets    20186  2018   Â£
# 267                                    tangible assets    12841  2017   Â£
# 268                                             stocks  1196489  2018   Â£
# 269                                             stocks   594500  2017   Â£
# 270                                            debtors   293986  2018   Â£
# 271                                            debtors   166895  2017   Â£
# 272                           cash at bank and in hand     1795  2018   Â£
# 273                           cash at bank and in hand    99276  2017   Â£
# 274      creditors amounts falling due within one year  1461658  2018   Â£
# 275      creditors amounts falling due within one year   767353  2017   Â£
# 276                                 net current assets    30612  2018   Â£
# 277                                 net current assets    93318  2017   Â£
# 278              total assets less current liabilities    50798  2018   Â£
# 279              total assets less current liabilities   106159  2017   Â£
# 280                                         net assets    50798  2018   Â£
# 281                                         net assets   106159  2017   Â£
# 282                            called up share capital   100000  2018   Â£
# 283                            called up share capital   100000  2017   Â£
# 284                            profit and loss account    49202  2018   Â£
# 285                            profit and loss account     6159  2017   Â£
# 286                                 shareholders funds    50798  2018   Â£
# 287                                 shareholders funds   106159  2017   Â£
# 14                                     tangible assets     9595  2018   Â£
# 15                                     tangible assets    18671  2017   Â£
# 16                                              stocks     2100  2018   Â£
# 17                                              stocks     2100  2017   Â£
# 18         debtors amounts falling due within one year   372307  2018   Â£
# 19         debtors amounts falling due within one year   434429  2017   Â£
# 20                            cash at bank and in hand   141878  2018   Â£
# 21                            cash at bank and in hand    46517  2017   Â£
# ..                                                 ...      ...   ...  ...
# 674                            transfers between funds    30000  2018   Â£
# 675                            transfers between funds    30000  2017   Â£
# 676                        total funds brought forward    16250  2018   Â£
# 677                        total funds brought forward   485861  2017   Â£
# 678                        total funds carried forward    27638  2018   Â£
# 679                        total funds carried forward   535534  2017   Â£
# 680                      general designated restricted     2018  2018   Â£
# 681                      general designated restricted     2017  2017   Â£
# 682                             donations and legacies        2  2018   Â£
# 683                             donations and legacies   489283  2017   Â£
# 684                              charitable activities        3  2018   Â£
# 685                              charitable activities   189557  2017   Â£
# 686                                  investment income        5  2018   Â£
# 687                                  investment income      101  2017   Â£
# 688                                      raising funds        6  2018   Â£
# 689                                      raising funds    20539  2017   Â£
# 690                              charitable activities        7  2018   Â£
# 691                              charitable activities   600256  2017   Â£
# 692  157301 783096 679940 total expenditure 620795 ...    58146  2018   Â£
# 693  157301 783096 679940 total expenditure 620795 ...    14051  2017   Â£
# 694  net incomeexpenditure before transfers between...    58146  2018   Â£
# 695  net incomeexpenditure before transfers between...    14051  2017   Â£
# 696                            transfers between funds       23  2018   Â£
# 697                            transfers between funds    20000  2017   Â£
# 698                              net movement in funds    38146  2018   Â£
# 699                              net movement in funds    14051  2017   Â£
# 700                        total funds brought forward   535534  2018   Â£
# 701                        total funds brought forward   485861  2017   Â£
# 702                        total funds carried forward   574629  2018   Â£
# 703                        total funds carried forward   535534  2017   Â£
#
# [704 rows x 9 columns]

# %%
df = pd.concat([sus_df, conf_df])
# Out:
# /home/edd/.local/share/virtualenvs/explore-1I3eoxiK/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      OK?     all_reasons  conf  conf_quart             filename  \
# 20     y  value is year?    93         NaN  00645015_2019-01-03
# 21     y  value is year?    96         NaN  00645015_2019-01-03
# 6      y  value is year?    95         NaN  00645015_2019-01-03
# 7      y  value is year?    96         NaN  00645015_2019-01-03
# 14     y  value is year?    96         NaN  00645015_2019-01-03
# 15     y  value is year?    96         NaN  00645015_2019-01-03
# 8      y  value is year?    96         NaN  00645015_2019-01-03
# 9      y  value is year?    96         NaN  00645015_2019-01-03
# 4      y  value is year?    96         NaN  00645015_2019-01-03
# 5      y  value is year?    96         NaN  00645015_2019-01-03
# 0      y  value is year?    87         NaN  00645015_2019-01-03
# 1      y  value is year?    87         NaN  00645015_2019-01-03
# 22     y  value is year?    69         NaN  00645015_2019-01-03
# 23     y  value is year?    95         NaN  00645015_2019-01-03
# 18     y  value is year?    95         NaN  00645015_2019-01-03
# 19     y  value is year?    96         NaN  00645015_2019-01-03
# 10     y  value is year?    95         NaN  00645015_2019-01-03
# 11     y  value is year?    95         NaN  00645015_2019-01-03
# 24     y  value is year?    95         NaN  00645015_2019-01-03
# 25     y  value is year?    94         NaN  00645015_2019-01-03
# 16     y  value is year?    96         NaN  00645015_2019-01-03
# 17     y  value is year?    96         NaN  00645015_2019-01-03
# 2      y  value is year?    96         NaN  00645015_2019-01-03
# 3      y  value is year?    96         NaN  00645015_2019-01-03
# 12     y  value is year?    92         NaN  00645015_2019-01-03
# 13     y  value is year?    96         NaN  00645015_2019-01-03
# 26     y  value is year?    49         NaN  00645015_2019-01-03
# 27     y  value is year?    96         NaN  00645015_2019-01-03
# 40     y  value is year?    96         NaN  00904957_2018-09-13
# 41     y  value is year?    96         NaN  00904957_2018-09-13
# ..   ...             ...   ...         ...                  ...
# 674  NaN             NaN    96         2.0  SC094096_2018-10-03
# 675  NaN             NaN    96         2.0  SC094096_2018-10-03
# 676  NaN             NaN    94         2.0  SC094096_2018-10-03
# 677  NaN             NaN    96         2.0  SC094096_2018-10-03
# 678  NaN             NaN    94         2.0  SC094096_2018-10-03
# 679  NaN             NaN    96         2.0  SC094096_2018-10-03
# 680  NaN             NaN    95         2.0  SC094096_2018-10-03
# 681  NaN             NaN    96         2.0  SC094096_2018-10-03
# 682  NaN             NaN    96         2.0  SC094096_2018-10-03
# 683  NaN             NaN    96         2.0  SC094096_2018-10-03
# 684  NaN             NaN    96         2.0  SC094096_2018-10-03
# 685  NaN             NaN    97         2.0  SC094096_2018-10-03
# 686  NaN             NaN    96         2.0  SC094096_2018-10-03
# 687  NaN             NaN    97         2.0  SC094096_2018-10-03
# 688  NaN             NaN    90         2.0  SC094096_2018-10-03
# 689  NaN             NaN    96         2.0  SC094096_2018-10-03
# 690  NaN             NaN    96         2.0  SC094096_2018-10-03
# 691  NaN             NaN    95         2.0  SC094096_2018-10-03
# 692  NaN             NaN    96         2.0  SC094096_2018-10-03
# 693  NaN             NaN    95         2.0  SC094096_2018-10-03
# 694  NaN             NaN    96         2.0  SC094096_2018-10-03
# 695  NaN             NaN    88         2.0  SC094096_2018-10-03
# 696  NaN             NaN    96         2.0  SC094096_2018-10-03
# 697  NaN             NaN    96         2.0  SC094096_2018-10-03
# 698  NaN             NaN    96         2.0  SC094096_2018-10-03
# 699  NaN             NaN    95         2.0  SC094096_2018-10-03
# 700  NaN             NaN    95         2.0  SC094096_2018-10-03
# 701  NaN             NaN    94         2.0  SC094096_2018-10-03
# 702  NaN             NaN    96         2.0  SC094096_2018-10-03
# 703  NaN             NaN    96         2.0  SC094096_2018-10-03
#
#                                                  label notes unit     value  \
# 20                             called up share capital   NaN    £      2002
# 21                             called up share capital   NaN    £      2002
# 6                             cash at bank and in hand   NaN    £    166665
# 7                             cash at bank and in hand   NaN    £     98022
# 14   creditors amounts falling due after more than ...   NaN    £    695701
# 15   creditors amounts falling due after more than ...   NaN    £    843126
# 8        creditors amounts falling due within one year   NaN    £    225565
# 9        creditors amounts falling due within one year   NaN    £     73966
# 4                                              debtors   NaN    £    375921
# 5                                              debtors   NaN    £    274518
# 0                                investment properties   NaN    £    905000
# 1                                investment properties   NaN    £    905000
# 22                        investment property reserves   NaN    £   4818572
# 23                        investment property reserves   NaN    £   4815651
# 18                                          net assets   NaN    £   6672447
# 19                                          net assets   NaN    £   6503654
# 10                                  net current assets   NaN    £   6937873
# 11                                  net current assets   NaN    £   6919426
# 24                            profit and loss reserves   NaN    £   1851873
# 25                            profit and loss reserves   NaN    £   1686001
# 16                          provisions for liabilities   NaN    £    474725
# 17                          provisions for liabilities   NaN    £    477646
# 2                                               stocks   NaN    £   6620852
# 3                                               stocks   NaN    £   6620852
# 12               total assets less current liabilities   NaN    £   7842873
# 13               total assets less current liabilities   NaN    £   7824426
# 26                                        total equity   NaN    £   6672447
# 27                                        total equity   NaN    £   6503654
# 40                 amounts falling due within one year   NaN    £  31665959
# 41                 amounts falling due within one year   NaN    £  28196177
# ..                                                 ...   ...  ...       ...
# 674                            transfers between funds   NaN   Â£     30000
# 675                            transfers between funds   NaN   Â£     30000
# 676                        total funds brought forward   NaN   Â£     16250
# 677                        total funds brought forward   NaN   Â£    485861
# 678                        total funds carried forward   NaN   Â£     27638
# 679                        total funds carried forward   NaN   Â£    535534
# 680                      general designated restricted   NaN   Â£      2018
# 681                      general designated restricted   NaN   Â£      2017
# 682                             donations and legacies   NaN   Â£         2
# 683                             donations and legacies   NaN   Â£    489283
# 684                              charitable activities   NaN   Â£         3
# 685                              charitable activities   NaN   Â£    189557
# 686                                  investment income   NaN   Â£         5
# 687                                  investment income   NaN   Â£       101
# 688                                      raising funds   NaN   Â£         6
# 689                                      raising funds   NaN   Â£     20539
# 690                              charitable activities   NaN   Â£         7
# 691                              charitable activities   NaN   Â£    600256
# 692  157301 783096 679940 total expenditure 620795 ...   NaN   Â£     58146
# 693  157301 783096 679940 total expenditure 620795 ...   NaN   Â£     14051
# 694  net incomeexpenditure before transfers between...   NaN   Â£     58146
# 695  net incomeexpenditure before transfers between...   NaN   Â£     14051
# 696                            transfers between funds   NaN   Â£        23
# 697                            transfers between funds   NaN   Â£     20000
# 698                              net movement in funds   NaN   Â£     38146
# 699                              net movement in funds   NaN   Â£     14051
# 700                        total funds brought forward   NaN   Â£    535534
# 701                        total funds brought forward   NaN   Â£    485861
# 702                        total funds carried forward   NaN   Â£    574629
# 703                        total funds carried forward   NaN   Â£    535534
#
#      year
# 20   2018
# 21   2017
# 6    2018
# 7    2017
# 14   2018
# 15   2017
# 8    2018
# 9    2017
# 4    2018
# 5    2017
# 0    2018
# 1    2017
# 22   2018
# 23   2017
# 18   2018
# 19   2017
# 10   2018
# 11   2017
# 24   2018
# 25   2017
# 16   2018
# 17   2017
# 2    2018
# 3    2017
# 12   2018
# 13   2017
# 26   2018
# 27   2017
# 40   2017
# 41   2016
# ..    ...
# 674  2018
# 675  2017
# 676  2018
# 677  2017
# 678  2018
# 679  2017
# 680  2018
# 681  2017
# 682  2018
# 683  2017
# 684  2018
# 685  2017
# 686  2018
# 687  2017
# 688  2018
# 689  2017
# 690  2018
# 691  2017
# 692  2018
# 693  2017
# 694  2018
# 695  2017
# 696  2018
# 697  2017
# 698  2018
# 699  2017
# 700  2018
# 701  2017
# 702  2018
# 703  2017
#
# [2892 rows x 10 columns]

# %% [markdown]
# there might be duplicates so we drop them based on filename and label

# %%
df.shape
# Out:
# (2892, 10)

# %%
df.drop_duplicates(subset=["filename", "label","year","OK?"], keep="first").shape
# Out:
# (2688, 10)

# %% [markdown]
# Individual value confidence
#
# Here we look at the data we have and see if confidence is a good predictor of whether or not the data is correct or not.
#
# Lets create a dummy variable for OK? called correct

# %%
df["OK?"]  = df["OK?"].str.replace(" ", "")

# %%
df.dropna(subset=["OK?"],inplace=True)

# %%
df["correct"] = pd.get_dummies(df["OK?"])["y"]

# %% [markdown]
# some values we can explain and they are not to do with misreads, we only want misreads
#
# (these aren't super consistent, my fault!)

# %%
df.notes.unique().tolist()
# Out:
# [nan,
#  'total assets less current liabilites \x96 across two lines',
#  'note should be year',
#  'notes is year',
#  'should be year',
#  'picked up incorrect figure \x96 should be 2007 - unit is incorrect \x96 should be £',
#  'picked up incorrect figure \x96 should be 1090, unit is incorrect \x96 should be £',
#  'handwritten year and little information',
#  'file missing assets',
#  'shoud be: 291,346 confused by comma',
#  'shoud be: 366,491 confused by comma',
#  'year as value',
#  'should be debtors \x96 and cash at back as seperate',
#  'unclear where numbers are coming from',
#  'missing text should be total assets less current liabilites and net assets',
#  'incorrect text \x96 no il',
#  'incorrect value should be 705035',
#  'incorrect value \x96 should be -',
#  'incorrect value \x96 should be 6038442',
#  'is year',
#  'incorrect value \x96 should be 2438330',
#  'date/year -should not be included',
#  'should not be included',
#  'should be cash not gash',
#  'value incorrect \x96 should be 1243834',
#  'mistaken date',
#  'value incorrect \x96 should be 8297250',
#  'value incorrect \x96 should be 7779868',
#  'value incorrect \x96 1366629',
#  'not clear where this has come from',
#  'value incorrect \x96 1112106',
#  'label incorrect',
#  'value incorrect \x96 6203, label incorrect',
#  'value incorrect \x96 6173, label incorrect',
#  'label incorrect \x96 should be investments',
#  'label incorrect \x96 should be split into two: ordinary shares and accumulated losses',
#  'label incorrect \x96 remove il',
#  'label incorrect \x96 should be amoutns falling due within one year',
#  'label incorrect \x96 should be stocks',
#  'value is year',
#  'is date',
#  'unit incorrect \x96 should be £000',
#  'note a value',
#  'incorrrect label \x96 missing; due within one year',
#  'should be two values \x96 debtors should be -',
#  'not a value',
#  'label incorrect \x96 should be cash in bank at hand',
#  'incorrect year',
#  'unit incorrect \x96 should be £000, notes is year',
#  'label incorrect \x96 remove vel',
#  'incorrect year \x96 should be 2016',
#  'incorrect year \x96 should be 2015',
#  'incorrect label \x96 should be debtors and  cash at bank and in hand',
#  'units should be £ ',
#  'incorrect label \x96 shoud be net',
#  'note is year',
#  'label incorrect \x96 remove sip es',
#  'label incorrect \x96 sip es',
#  'should be two values \x96 called up share capital and profit and loss account',
#  'label incorrect \x96 c should be s',
#  'should be two values \x96 called up share capital and share premium ',
#  'note clear where this has come from',
#  'notes as year',
#  'incorrect year ; incorrect value',
#  'incorrect year, should be two values creditors amounts falling due within one year and net current assests',
#  'is not value',
#  'label incorrect \x96 total',
#  'label incorrect \x96 remove oo',
#  'label incorrect \x96 missing year on second line',
#  'incorrect value, incorrect label',
#  'label incorrect \x96 remove v',
#  'label incorrect \x96 remove reo',
#  'incorrect value- 880',
#  'incorrect label \x96 total',
#  'units incorrect \x96 should be $000',
#  'units incorrect \x96 should be $000, label incorrect, should be investments',
#  'incorrect year, label incorrect, remove none',
#  'value incorrect \x96 117',
#  'value incorrect \x96 86',
#  'note is unit',
#  'note clear where this has come from \x96 missing values',
#  'incorrect value \x96 should be 1',
#  'incorrect value \x96 should be 180467',
#  'value incorrect \x96 58540',
#  'incorrect date, incorrect value',
#  'Incorrect year, incorrect value \x96 is note',
#  'incorrect date, incorrect value \x96 is note',
#  'unit incorrect \x96 should be EUR',
#  'label incorrect \x96 should be members capital classified as equity and other reseves',
#  'incorrect value \x96 is note, shouold be -',
#  'incorrect date',
#  'incorrect date, label incorrect',
#  'label incorrect, value incorrect',
#  'value incorrect',
#  'value incorrect -783096',
#  'unit incorrect \x96 should be £',
#  'value is date',
#  'is not a value',
#  'not clear where this is from',
#  'label incorrect â\x80\x93 misspelling',
#  'value incorrect â\x80\x93 1243834',
#  'value incorrect â\x80\x93  1112106',
#  'label incorrect ',
#  'value incorrect â\x80\x93 8297350',
#  'value incorrect â\x80\x93 7779868',
#  'value incorrect- 1366629',
#  'misspelling, is year',
#  'misspelling',
#  'should be two values',
#  'incorrect year â\x80\x93 2017',
#  'incorrect value ',
#  'not clear on date',
#  'value incorrect â\x80\x93 4500',
#  'date incorrect',
#  'is two values',
#  'should be three values',
#  'year incorrect',
#  'incorrect value â\x80\x93 127844',
#  'value incorrect â\x80\x93  461',
#  'incorrect year â\x80\x93 2018']

# %%
drop_reasons = ['note should be year',
               'notes is year',
               'should be year'
               'is year',
               'is date',
               'note a value',
               'not a value',
               'note is year',
               'notes as year',
               'is not value',
               'note is unit',
               'is not a value',
               'unclear where numbers are coming from',
               'should not be included',
               'date/year -should not be included',
               'not clear where this has come from',
               'note clear where this has come from',
               'not clear where this is from'   
               ]

# %%
# Out:
# array([1, 0], dtype=uint64)

# %% [markdown]
# model
#
# we fit and evaluate on one set as we are not testing predicitive power here but explanatory power.

# %%
log_mdl = LogisticRegression()

# %%
y = df.correct.values
X = df.conf.values.reshape(-1,1)

# %%
log_mdl.fit(X,y)
# Out:
# /home/edd/.local/share/virtualenvs/explore-1I3eoxiK/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
results = log_mdl.predict_proba(X)

# %%
plot.scatter(X,y)

# %%
model_report = ConfusionMatrix(log_mdl, 
                               classes=[1,0])

# %%
model_report.fit(X,y)
model_report.score(X,y)
g=model_report.poof()
# Out:
# /home/edd/.local/share/virtualenvs/explore-1I3eoxiK/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
